# %% [markdown]
# ## **Scraping** Data Twitter

# %% [markdown]
# coolect data twitter menggunakan Library TWEEPY dengan kombinasi API twitter terhadap spesifikasi keywoard. untuk dokumentasi lengkap tweepy bisa dilihat pada link berikut [Link>>](https://tweepy.readthedocs.io/en/latest/)

# %%
# Install Library
# !pip install tweepy

# %%
# Import Library
import tweepy
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Buat Apps di twitter agar bisa menggunakan [API](https://apps.twitter.com)

# %%
# Fill the API Key
API_key = 'sr37cQ6tjAIbnZtHgCkWcAmIG'
API_secret = 'NnRqsMPvV5jS8wn9uV63X71vUAQCXlTzA5BllqXWKM9wga60bn'
access_token = '3245709469-qc9C9VEQLzmhNHkwD0E9A9MopPajM81pGnbPHe4'
access_token_secret = 'n5OAqOyQZi3TnQBC20QRWmNiOESxtBAB8SnZBSwPHVSKA'

# %%
# Auth. 
auth = tweepy.OAuthHandler(API_key, API_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
# Finding tweets by Keyword
tweets = api.search('watashi', count=1000, lang='id')

# %%
# Show Tweets
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f792b332c50>, _json={'created_at': 'Tue Apr 27 21:18:34 +0000 2021', 'id': 1387154227743444993, 'id_str': '1387154227743444993', 'text': '@watashi_NoUso 😂😂😂😂 sesekali tiber', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'watashi_NoUso', 'name': 'Athlete Kaki Cantik', 'id': 985138782541266944, 'id_str': '985138782541266944', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'in', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1387153895495847937, 'in_reply_to_status_id_str': '1387153895495847937', 'in_reply_to_user_id': 985138782541266944, 'in_reply_to_user_id_str': '985138782541266944', 'in_reply_to_screen_name': 'watashi_NoUso', 'user': {'id': 1228543668199407617, 'id_str': '1228543668199407617', 'name': 'Dani', 'screen_name': 'Danewwwww', 'location': '', 'description': '𝒎
# ...

# %%
# Print the collected tweet
data = pd.DataFrame()
data['Created At'] = [tweet.created_at for tweet in tweets]
data['Screen Name'] = [tweet.user.screen_name for tweet in tweets]
data['Tweet'] = [tweet.text for tweet in tweets]
data['Location'] = [tweet.user.location for tweet in tweets]
data['Number of Retweet'] = [tweet.retweet_count for tweet in tweets]
data['Number of Like'] = [tweet.favorite_count for tweet in tweets]
display(data.head(25))
# Out:
#             Created At      Screen Name  ... Number of Retweet Number of Like
# 0  2021-04-27 21:18:34        Danewwwww  ...                 0              0
# 1  2021-04-27 21:17:15    watashi_NoUso  ...                 0              0
# 2  2021-04-27 21:16:42         eddeFNBR  ...                 0              0
# 3  2021-04-27 21:13:44    watashi_NoUso  ...                 0              0
# 4  2021-04-27 21:12:13       ToastyBun_  ...                 0              0
# 5  2021-04-27 20:58:54        miy4srize  ...                 0              1
# 6  2021-04-27 20:56:33    watashi_NoUso  ...               371              0
# 7  2021-04-27 20:55:17      simply_sora  ...                 0              0
# 8  2021-04-27 20:54:52    watashi_NoUso  ...                 0              0
# 9  2021-04-27 20:52:53  shoyonunpoposu2  ...                 0              2
# 10 2021-04-27 20:36:22    watashi_NoUso  ...                 0              0
# ...

# %%
# Save as .CSV
data.to_csv('/content/drive/My Drive/Colab Notebooks/Scraping Twitter/scraping-tweet.csv')
