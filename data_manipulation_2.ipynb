# %% [markdown]
# ## **NO 1**

# %%
import nltk
nltk.download('brown')

news_text = brown.sents(categories='news')
mytext=news_text[7]
print(mytext)
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# ['Merger', 'proposed']

# %% [markdown]
# ## **NO 2 A**

# %%
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
filtered_words = [word for word in mytext if word not in stop_words]
print(filtered_words)
# Out:
# ['The', 'jury', 'said', 'term-end', 'presentments', 'City', 'Executive', 'Committee', ',', 'over-all', 'charge', 'election', ',', '``', 'deserves', 'praise', 'thanks', 'City', 'Atlanta', "''", 'manner', 'election', 'conducted', '.']

# %% [markdown]
# ## **NO 2 B**

# %%
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
stemmed = [porter.stem(word) for word in filtered_words]
print(stemmed)
# Out:
# ['the', 'juri', 'said', 'term-end', 'present', 'citi', 'execut', 'committe', ',', 'over-al', 'charg', 'elect', ',', '``', 'deserv', 'prais', 'thank', 'citi', 'atlanta', "''", 'manner', 'elect', 'conduct', '.']

# %% [markdown]
# ## **NO 2 C**

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

pos = pos_tag(stemmed)
print(pos)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('the', 'DT'), ('juri', 'NN'), ('said', 'VBD'), ('term-end', 'JJ'), ('present', 'JJ'), ('citi', 'NN'), ('execut', 'NN'), ('committe', 'NN'), (',', ','), ('over-al', 'JJ'), ('charg', 'NN'), ('elect', 'NN'), (',', ','), ('``', '``'), ('deserv', 'NN'), ('prais', 'NN'), ('thank', 'NN'), ('citi', 'NN'), ('atlanta', 'NN'), ("''", "''"), ('manner', 'NN'), ('elect', 'JJ'), ('conduct', 'NN'), ('.', '.')]

# %% [markdown]
# ## **NO 4**

# %%
from nltk.collocations import BigramCollocationFinder
bigram_measures = nltk.collocations.BigramAssocMeasures()


finder = BigramCollocationFinder.from_words((mytext))
print(finder.nbest(bigram_measures.pmi, 10))
# Out:
# [('Merger', 'proposed')]

# %% [markdown]
# ## **NO 5**
# Terdapat beberapa penyesuaian antara koding , jadi perlu perubahan agar bisa berjalan pada google colab dengan lancar
